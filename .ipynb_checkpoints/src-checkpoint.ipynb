# %% [markdown]
# ## Imports and working directory configuration

# %%
# import plugin to reload automatically changes in the python scripts
# %load_ext autoreload
# %autoreload 2

# check the current working directory
import os
print(os.getcwd())
# %cd '/Users/michal/PycharmProjects/covidout/'

# import external scripts and libraries
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import io
import imageio

import visualisations as vis, ioops, spreading
# Out:
# /home/mipo57/projekty/covidout_graph/spreading_model
# [Errno 2] No such file or directory: '/Users/michal/PycharmProjects/covidout/'
# /home/mipo57/projekty/covidout_graph/spreading_model
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-4840bdc1b1fc> in <module>
#       9
#      10 # import external scripts and libraries
# ---> 11 import networkx as nx
#      12 import matplotlib.pyplot as plt
#      13 import numpy as np
#
# ModuleNotFoundError: No module named 'networkx'

# %% [markdown]
# ### IO and short viz

# %%
g = ioops.read_net('networks/nod2.csv', 'networks/edg2.csv')

# print(g.nodes(data=True))
# print(g.edges(data=True))

# %%
# extract subgraph to plot
_g = vis._filter(g, 649, 2)

pos = nx.spring_layout(_g)
_ = vis.plot(_g, n_labels=True, e_labels=False)

# %%
# load network
g = ioops.read_net('networks/nod2.csv', 'networks/edg2.csv')

# extract node to take a close look at and degree of neighbourhood
node_of_interest = 649
ngrhd_degree = 2

# initialse container for images
imgs = []


# plot initial state of network
pos = nx.spring_layout(_g)
_g = vis._filter(g, node_of_interest, ngrhd_degree)
imgs.append(vis.plot(_g, False, False, pos))

spreading.sperad(g, node_of_interest, True)

# perform propagation in 10 epochs
for i in range(10):
    # propagate
    _ = spreading.sperad(g, node_of_interest)

    # plot initial state of network
    _g = vis._filter(g, node_of_interest, ngrhd_degree)
    imgs.append(vis.plot(_g, False, False, pos))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-56-2970ce452f9a> in <module>
#      18 for i in range(10):
#      19     # propagate
# ---> 20     _ = spreading.sperad(g, node_of_interest)
#      21
#      22     # plot initial state of network
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
# ...
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      81         # update new probability computed from external conditions
#      82         #G.nodes[n]['w'] = 1 - prob
# ---> 83
#      84         visited.add(n)
#      85         sperad(G, n, visited)
#
# ~/projekty/covidout/spreading_model/spreading.py in sperad(G, ill_node, visited)
#      60
#      61         for neigbour in _n:
# ---> 62             neigbour_prob = G.nodes[neigbour]['prob']
#      63             relation_prob = G.edges[(n, neigbour)]['w']
#      64             values_1 = pd.DataFrame.from_dict(G.nodes[n]['state'], orient="index").values
#
# ~/.virtualenvs/coronaOut/lib/python3.7/site-packages/pandas/core/frame.py in from_dict(cls, data, orient, dtype, columns)
#    1245             raise ValueError("only recognize index or columns for orient")
#    1246
# -> 1247         return cls(data, index=index, columns=columns, dtype=dtype)
#    1248
#    1249     def to_numpy(self, dtype=None, copy=False) -> np.ndarray:
#
# ~/.virtualenvs/coronaOut/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     486                     mgr = arrays_to_mgr(arrays, columns, index, columns, dtype=dtype)
#     487                 else:
# --> 488                     mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
#     489             else:
#     490                 mgr = init_dict({}, index, columns, dtype=dtype)
#
# ~/.virtualenvs/coronaOut/lib/python3.7/site-packages/pandas/core/internals/construction.py in init_ndarray(values, index, columns, dtype, copy)
#     179                 ) from orig
#     180
# --> 181     index, columns = _get_axes(*values.shape, index=index, columns=columns)
#     182     values = values.T
#     183
#
# ~/.virtualenvs/coronaOut/lib/python3.7/site-packages/pandas/core/internals/construction.py in _get_axes(N, K, index, columns)
#     422         index = ibase.default_index(N)
#     423     else:
# --> 424         index = ensure_index(index)
#     425
#     426     if columns is None:
#
# ~/.virtualenvs/coronaOut/lib/python3.7/site-packages/pandas/core/indexes/base.py in ensure_index(index_like, copy)
#    5355             index_like = copy(index_like)
#    5356
# -> 5357     return Index(index_like)
#    5358
#    5359
#
# ~/.virtualenvs/coronaOut/lib/python3.7/site-packages/pandas/core/indexes/base.py in __new__(cls, data, dtype, copy, name, tupleize_cols, **kwargs)
#     293
#     294         # categorical
# --> 295         elif is_categorical_dtype(data) or is_categorical_dtype(dtype):
#     296             # Delay import for perf. https://github.com/pandas-dev/pandas/pull/31423
#     297             from pandas.core.indexes.category import CategoricalIndex
#
# ~/.virtualenvs/coronaOut/lib/python3.7/site-packages/pandas/core/dtypes/common.py in is_categorical_dtype(arr_or_dtype)
#     570     if arr_or_dtype is None:
#     571         return False
# --> 572     return CategoricalDtype.is_dtype(arr_or_dtype)
#     573
#     574
#
# ~/.virtualenvs/coronaOut/lib/python3.7/site-packages/pandas/core/dtypes/base.py in is_dtype(cls, dtype)
#     271         dtype = getattr(dtype, "dtype", dtype)
#     272
# --> 273         if isinstance(dtype, (ABCSeries, ABCIndexClass, ABCDataFrame, np.dtype)):
#     274             # https://github.com/pandas-dev/pandas/issues/22960
#     275             # avoid passing data to `construct_from_string`. This could
#
# KeyboardInterrupt:

# %%
xdd = []
for img in imgs:
    xdd.append(imageio.imread(img))

imageio.mimsave(os.getcwd() + '/networks/experiment.gif', xdd, duration=.5)

# %%
#for n in g.nodes():
vis.plot(g, 2, 5)
ioops.get_node_states(g)
# Out:
# '{"0": 0.9999999999907745, "1": 1.0, "2": 1.0, "3": 1.0, "4": 1.0, "5": 1.882308753309303e-10, "6": 1.0, "7": 1.0, "8": 1.0, "9": 0.7309339685644891, "10": 1.0, "11": 1.0, "12": 1.0, "13": 0.9999993247750313, "14": 0.9999999999989502, "15": 1.0, "16": 0.9999999637716089, "17": 0.5532987297216156, "18": 0.999997851347587, "19": 1.0, "20": 0.9897778881366259, "21": 1.0, "22": 0.9999992496963147, "23": 0.999999999999999, "24": 1.0, "25": 1.0, "26": 0.9999999999999999, "27": 1.0, "28": 0.3277048288024798, "29": 0.9999996690938798, "30": 1.0, "31": 0.9999999771067438, "32": 1.0, "33": 1.0, "34": 0.9999999999999974, "35": 0.9999999980990422, "36": 1.0, "37": 1.0, "38": 1.0, "39": 1.0, "40": 0.9999998708348288, "41": 1.0, "42": 1.0, "43": 1.1257689958021899e-07, "44": 1.0, "45": 0.9979222545973189, "46": 1.0, "47": 1.0, "48": 1.0, "49": 0.9999999884418098, "50": 0.9999999999914732, "51": 1.0, "52": 1.0, "53": 0.6033761822053982, "54": 1.0, "55": 1.0, "56": 1.0, "57": 1.0, "58": 0.999999999999999, "59": 1.0, "60": 0.999996130057221, "61": 0.9999765203348737, "62": 1.0, "63": 1.0, "64": 1.0, "65": 1.0, "66": 0.9999999999676886, "67": 1.0, "68": 0.9999999999998757, "69": 0.999999999905508, "70": 0.4578540921135274, "71": 0.999999999989536, "72": 0.9586783952163217, "73": 0.9999999999999996, "74": 1.0, "75": 1.0, "76": 0.9999999999998999, "77": 0.9999999999999785, "78": 0.9999999999999996, "79": 1.0, "80": 1.0, "81": 1.0, "82": 1.0, "83": 