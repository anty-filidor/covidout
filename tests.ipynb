# %% [markdown]
# ## Imports and working directory configuration

# %%
# import plugin to reload automatically changes in the python scripts
# %load_ext autoreload
# %autoreload 2

# check the current working directory
import os
print(os.getcwd())

# import external scripts and libraries
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import io

import visualisations as vis, ioops, spreading
# Out:
# /Users/michal/PycharmProjects/covidout

# %% [markdown]
# ### IO test

# %%
g = ioops.read_net('nodes.csv', 'edges.csv')

print(g.nodes(data=True))
print(g.edges(data=True))
# Out:
# [(0, {'w': 0.021772742702073664}), (28, {'w': 0.021772742702073664}), (2, {'w': 0.0}), (4, {'w': 0.021918464423191453}), (10, {'w': 0.06502678466398541}), (17, {'w': 0.00029144344223558014}), (31, {'w': 0.47779009213457313}), (5, {'w': 0.021772742702073664}), (20, {'w': 0.06488106294286763}), (8, {'w': 0.021918464423191453}), (12, {'w': 0.00014572172111779007}), (9, {'w': 0.021772742702073664}), (22, {'w': 0.0}), (38, {'w': 0.00029144344223558014}), (11, {'w': 0.0}), (24, {'w': 0.0004371651633533702}), (15, {'w': 0.021627020980955876}), (27, {'w': 0.021627020980955876}), (23, {'w': 0.00029144344223558014}), (35, {'w': 0.00014572172111779007}), (37, {'w': 0.021627020980955876}), (1, {'w': 0.0}), (3, {'w': 0.00014572172111779007}), (6, {'w': 0.00014572172111779007}), (7, {'w': 0.021627020980955876}), (13, {'w': 0.0}), (14, {'w': 0.0}), (16, {'w': 0.043545485404147335}), (18, {'w': 0.4345360501726614}), (19, {'w': 0.021627020980955876}), (21, {'w': 0.00029144344223558014}), (25, {'w': 0.00014572172111779007}), (26, {'w': 0.43439032845154363}), (29, {'w': 0.043399763683029544}), (30, {'w': 0.021627020980955876}), (32, {'w': 0.04369120712526512}), (33, {'w': 0.45616307115361726}), (34, {'w': 0.0}), (36, {'w': 0.4345360501726614}), (39, {'w': 0.021918464423191453})]
# [(0, 28, {'w': 0.3685709526503136}), (2, 4, {'w': 0.3691728889229796}), (2, 10, {'w': 0.045858023562701855}), (2, 17, {'w': 0.4665224782116673}), (2, 31, {'w': 0.38867417202049015}), (4, 5, {'w': 0.3806518427144572}), (4, 17, {'w': 0.3315799322232129}), (4, 20, {'w': 0.8310386999677465}), (10, 31, {'w': 0.8785335813376517}), (17, 20, {'w': 0.2418459378507597}), (5, 20, {'w': 0.8567456825029127}), (8, 12, {'w': 0.4114122898022008}), (12, 15, {'w': 0.43523242049910094}), (12, 27, {'w': 0.4145024868228052}), (9, 22, {'w': 0.08766138838868652}), (9, 38, {'w': 0.5795912123131142}), (11, 24, {'w': 0.9548716454865795}), (15, 27, {'w': 0.6875576562479785}), (27, 37, {'w': 0.3456911703490314}), (23, 35, {'w': 0.5583480026104718})]

# %%
#for n in g.nodes():
#    print(g.nodes[n])


vis.plot(g, 2, 2)
# Out:
#    status
# ID
# 2       d
# 4       a
# 5       a
# 10      a
# 17      a
# 20      a
# 31      b
#          status
# ID
# (2, 4)        a
# (2, 10)       a
# (2, 17)       a
# (2, 31)       a
# (4, 5)        a
# (4, 17)       a
# (4, 20)       b
# (5, 20)       b
# (10, 31)      b
# (17, 20)      a

# %%
v = spreading.sperad(g, 2)
print(v)
# Out:
# {2, 31}

# %%
vis.plot(g, 2, 2)
# Out:
#    status
# ID
# 2       d
# 4       a
# 5       a
# 10      a
# 17      a
# 20      a
# 31      d
#          status
# ID
# (2, 4)        a
# (2, 10)       a
# (2, 17)       a
# (2, 31)       a
# (4, 5)        a
# (4, 17)       a
# (4, 20)       b
# (5, 20)       b
# (10, 31)      b
# (17, 20)      a
